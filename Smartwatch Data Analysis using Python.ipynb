# %% [markdown]
# # smart data analysis on healthcare

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.graph_objects as go

# %%
# !pip install plotly

# %% [markdown]
# # IMPORTING DATASET

# %%
a=pd.read_csv("dailyActivity_merged.csv")

# %%
a
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
print(a.isnull().sum())
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %% [markdown]
# # For knowing the information about the dataset

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %%
a.size
# Out:
# 14100

# %%
a.index
# Out:
# RangeIndex(start=0, stop=940, step=1)

# %%
a.shape
# Out:
# (940, 15)

# %%
a.ndim
# Out:
# 2

# %% [markdown]
# # For selecting first 10

# %%
a.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
# 5  1503960366    4/17/2016        9705           6.48             6.48
# 6  1503960366    4/18/2016       13019           8.59             8.59
# 7  1503960366    4/19/2016       15506           9.88             9.88
# 8  1503960366    4/20/2016       10544           6.68             6.68
# 9  1503960366    4/21/2016        9819           6.34             6.34
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# ...

# %% [markdown]
# # For selecting last 10

# %%
a.tail(10)
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 930  8877689391     5/3/2016       10818       8.210000         8.210000
# 931  8877689391     5/4/2016       18193      16.299999        16.299999
# 932  8877689391     5/5/2016       14055      10.670000        10.670000
# 933  8877689391     5/6/2016       21727      19.340000        19.340000
# 934  8877689391     5/7/2016       12332       8.130000         8.130000
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 930                       0.0                1.39                      0.10
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %% [markdown]
# # Change datatype of date

# %%
a["ActivityDate"] = pd.to_datetime(a["ActivityDate"],format="%m/%d/%Y")

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    datetime64[ns]
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %%
a.drop_duplicates()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-04-12       13162       8.500000         8.500000
# 1    1503960366   2016-04-13       10735       6.970000         6.970000
# 2    1503960366   2016-04-14       10460       6.740000         6.740000
# 3    1503960366   2016-04-15        9762       6.280000         6.280000
# 4    1503960366   2016-04-16       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   2016-05-08       10686       8.110000         8.110000
# 936  8877689391   2016-05-09       20226      18.250000        18.250000
# 937  8877689391   2016-05-10       10733       8.150000         8.150000
# 938  8877689391   2016-05-11       21420      19.559999        19.559999
# 939  8877689391   2016-05-12        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
a["TotalSteps"]
# Out:
# 0      13162
# 1      10735
# 2      10460
# 3       9762
# 4      12669
#        ...
# 935    10686
# 936    20226
# 937    10733
# 938    21420
# 939     8064
# Name: TotalSteps, Length: 940, dtype: int64

# %% [markdown]
# # To find the people who had crossed more than 20000 steps

# %%
a[a['TotalSteps']>20000]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 50   1624580081   2016-05-01       36019      28.030001        28.030001
# 251  2347167796   2016-04-16       22244      15.080000        15.080000
# 437  4388161847   2016-05-07       22770      17.540001        17.540001
# 691  6962181067   2016-04-23       20031      13.240000        13.240000
# 728  7007744171   2016-04-29       20067      14.300000        13.420000
# 770  8053475328   2016-04-14       20159      15.970000        15.970000
# 771  8053475328   2016-04-15       20669      16.240000        16.240000
# 779  8053475328   2016-04-23       22359      17.190001        17.190001
# 780  8053475328   2016-04-24       22988      17.950001        17.950001
# 781  8053475328   2016-04-25       20500      15.690000        15.690000
# 794  8053475328   2016-05-08       22026      17.650000        17.650000
# 909  8877689391   2016-04-12       23186      20.400000        20.400000
# ...

# %% [markdown]
# # Relationship between totalsteps And Calories

# %%
plt.Figure(figsize=(70,72))
y=a['TotalSteps']
x=a['Calories']
plt.xlabel("calories")
plt.ylabel("TotalSteps")
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # Total number of active minutes in a day

# %%
label = ["Very Active Minutes", "Fairly Active Minutes", 
         "Lightly Active Minutes", "Inactive Minutes"]
counts = a[["VeryActiveMinutes", "FairlyActiveMinutes", 
               "LightlyActiveMinutes", "SedentaryMinutes"]].mean()
colors = ['yellow','lightgreen', "red", "blue"]

fig = go.Figure(data=[go.Pie(labels=label, values=counts)])
fig.update_layout(title_text='Total Active Minutes')
fig.update_traces(hoverinfo='label+percent', textinfo='percent', textfont_size=30,
                  marker=dict(colors=colors, line=dict(color='black', width=3)))
fig.show()
# Out:
# <div>                            <div id="453c43c0-a7ad-4ae2-82e7-0259bef3518b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("453c43c0-a7ad-4ae2-82e7-0259bef3518b")) {                    Plotly.newPlot(                        "453c43c0-a7ad-4ae2-82e7-0259bef3518b",                        [{"labels":["Very Active Minutes","Fairly Active Minutes","Lightly Active Minutes","Inactive Minutes"],"values":[21.164893617021278,13.564893617021276,192.8127659574468,991.2106382978724],"type":"pie","textfont":{"size":30},"marker":{"line":{"color":"black","width":3},"colors":["yellow","lightgreen","red","blue"]},"hoverinfo":"label+percent","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colo
# ...

# %% [markdown]
# # INDENTIFING THE RELATIONSHIP BETWEEN TotalDistance And Calories

# %%
plt.Figure(figsize=(4,4))
y=a['TotalDistance']
x=a['Calories']
plt.xlabel("calories")
plt.ylabel("TotalDistance")
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,marker='*')

# %%
plt.bar(x,y,10,4)
# Out:
# <BarContainer object of 940 artists>

# %%
plt.scatter(x,y)

# %%
plt.Figure(figsize=(4,4))
y=a['TotalDistance']
x=a['Calories']
plt.xlabel("calories")
plt.ylabel("TotalDistance")
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.plot(x,y)
plt.show()

# %%
sns.barplot(x,y)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Calories', ylabel='TotalSteps'>

# %%
sns.countplot(a['TotalDistance'],hue=a['Calories'])
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalDistance', ylabel='count'>

# %%
sns.boxplot(x=a['Calories'],y=a['TotalDistance'])
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='TotalDistance'>
